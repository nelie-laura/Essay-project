# %% [markdown]
# #***Analysis of Shuttle dataset***

# %% [markdown]
# ## Description of dataset[link text](https://archive.ics.uci.edu/ml/datasets/Statlog+(Shuttle)
# dataset contains 9 attributes all of which are numerical. The first one being time. The last column is the class which has been coded as follows :
# 1 Rad Flow
# 2 Fpv Close
# 3 Fpv Open
# 4 High
# 5 Bypass
# 6 Bpv Close
# 7 Bpv Open

# %%
#Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# import data
data_train = pd.read_csv('/content/drive/My Drive/shuttle/shuttledata.csv')
data_test=pd.read_csv('/content/drive/My Drive/shuttle/shuttle_test.csv')
print(data_train.shape)
data_train.head(5)
# Out:
# (43500, 10)
#    Time1  Time2  Time3  time4  Time5  Time6  Time7  Time8  Time9  Class
# 0     50     21     77      0     28      0     27     48     22      2
# 1     55      0     92      0      0     26     36     92     56      4
# 2     53      0     82      0     52     -5     29     30      2      1
# 3     37      0     76      0     28     18     40     48      8      1
# 4     37      0     79      0     34    -26     43     46      2      1

# %%
data_train.describe()
# Out:
#               Time1         Time2  ...         Time9         Class
# count  43500.000000  43500.000000  ...  43500.000000  43500.000000
# mean      48.249747     -0.205126  ...     13.964598      1.700529
# std       12.252618     78.142770  ...     25.648404      1.354648
# min       27.000000  -4821.000000  ...   -356.000000      1.000000
# 25%       38.000000      0.000000  ...      0.000000      1.000000
# 50%       45.000000      0.000000  ...      2.000000      1.000000
# 75%       55.000000      0.000000  ...     14.000000      1.000000
# max      126.000000   5075.000000  ...    266.000000      7.000000
#
# [8 rows x 10 columns]

# %%
data_test.head(5)
# Out:
#    Time1  Time2  Time3  Time4  Time5  Time6  Time7  Time8  Time9  Class
# 0     55      0     81      0     -6     11     25     88     64      4
# 1     56      0     96      0     52     -4     40     44      4      4
# 2     50     -1     89     -7     50      0     39     40      2      1
# 3     53      9     79      0     42     -2     25     37     12      4
# 4     55      2     82      0     54     -6     26     28      2      1

# %%
data_test.describe()
# Out:
#               Time1         Time2  ...         Time9         Class
# count  14500.000000  14500.000000  ...  14500.000000  14500.000000
# mean      48.203931      0.537586  ...     13.835862      1.677517
# std       12.194727     77.401196  ...     25.511220      1.339734
# min       27.000000  -3161.000000  ...   -264.000000      1.000000
# 25%       38.000000      0.000000  ...      0.000000      1.000000
# 50%       45.000000      0.000000  ...      2.000000      1.000000
# 75%       55.000000      0.000000  ...     14.000000      1.000000
# max      123.000000   4501.000000  ...    126.000000      7.000000
#
# [8 rows x 10 columns]

# %% [markdown]
# ## Analyzing of data

# %%
sns.countplot(x="Class",data=data_train)

# %%
sns.countplot(x="Class",data=data_test)

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43500 entries, 0 to 43499
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time1   43500 non-null  int64
#  1   Time2   43500 non-null  int64
#  2   Time3   43500 non-null  int64
#  3   time4   43500 non-null  int64
#  4   Time5   43500 non-null  int64
#  5   Time6   43500 non-null  int64
#  6   Time7   43500 non-null  int64
#  7   Time8   43500 non-null  int64
#  8   Time9   43500 non-null  int64
#  9   Class   43500 non-null  int64
# dtypes: int64(10)
# memory usage: 3.3 MB

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43500 entries, 0 to 43499
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time1   43500 non-null  int64
#  1   Time2   43500 non-null  int64
#  2   Time3   43500 non-null  int64
#  3   time4   43500 non-null  int64
#  4   Time5   43500 non-null  int64
#  5   Time6   43500 non-null  int64
#  6   Time7   43500 non-null  int64
#  7   Time8   43500 non-null  int64
#  8   Time9   43500 non-null  int64
#  9   Class   43500 non-null  int64
# dtypes: int64(10)
# memory usage: 3.3 MB

# %% [markdown]
# # We first use the Logistic Regression

# %%
x_train=data_train.drop(['Class'],axis=1)
x_test=data_test.drop(['Class'],axis=1)
y_train=data_train.Class
y_test =data_test.Class

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
# all parameters not specified are set to their defaults
log_Reg = LogisticRegression(penalty="l2",tol=0.00000000001,C=0.25,fit_intercept=False,intercept_scaling=14,random_state=2)

# %%
log_Reg.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=0.25, class_weight=None, dual=False, fit_intercept=False,
#                    intercept_scaling=14, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=2, solver='lbfgs', tol=1e-11, verbose=0,
#                    warm_start=False)

# %%
# Predict for One Observation (image)
test_pred=log_Reg.predict(x_test)

# %%
# Use score method to get accuracy of model
accury=accuracy_score(test_pred,y_test)
#score = log_Reg.score(x_test, y_test)
print(accury)
# Out:
# 0.9246896551724137

# %%
log_Reg?
